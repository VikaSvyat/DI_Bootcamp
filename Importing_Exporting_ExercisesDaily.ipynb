# %% [markdown]
# <a href="https://colab.research.google.com/github/VikaSvyat/DI_Bootcamp/blob/main/Importing_Exporting_ExercisesDaily.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f6ee2bfc-4b60-4c5f-8d6d-282194739167" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6ee2bfc-4b60-4c5f-8d6d-282194739167">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip 'Flower Color Images Dataset.zip'

# %%
# !ls
# Out:
# 'Flower Color Images Dataset'  'Flower Color Images Dataset.zip'   sample_data

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install tensorflow
! pip install keras
! pip install pillow

# %%
from PIL import Image, ImageOps

from matplotlib import pyplot as plt

# %%
# !ls
# !find /content -name "19_010.png"
# Out:
# 'Flower Color Images Dataset'	    flower-color-images.zip   sample_data
# 'Flower Color Images Dataset.zip'   kaggle.json
# /content/Flower Color Images Dataset/flowers/flowers/19_010.png

# %%
# Load an image using PIL
image_path = '/content/Flower Color Images Dataset/flowers/flowers/19_010.png'
original_image = Image.open(image_path)

# Display the original image using matplotlib
plt.imshow(original_image)

# %%
# !kaggle datasets download -d olgabelitskaya/flower-color-images
# Out:
# Dataset URL: https://www.kaggle.com/datasets/olgabelitskaya/flower-color-images
# License(s): other
# ...
#   0% 0.00/50.1M [00:00<?, ?B/s]
# 100% 50.1M/50.1M [00:00<00:00, 1.25GB/s]

# %%
from scipy.ndimage import rotate
def rotate_image_30_degrees(image):
  return rotate( image, 30, reshape=False, mode='nearest')

# %%
import numpy as np

# %%
image_array = np.array(original_image)

rotated = rotate_image_30_degrees(image_array)
Image.fromarray(rotated)
# Out:
# <PIL.Image.Image image mode=RGBA size=128x128>

# %%
h_flipped = ImageOps.mirror(original_image)

h_flipped
# Out:
# <PIL.Image.Image image mode=RGBA size=128x128>

# %%
v_flipped = ImageOps.flip(original_image)

v_flipped
# Out:
# <PIL.Image.Image image mode=RGBA size=128x128>

# %%
w, h = original_image.size
zoomed = original_image.resize((int(w * 1.2), int(h * 1.2)), Image.Resampling.LANCZOS)

zoomed
# Out:
# <PIL.Image.Image image mode=RGBA size=153x153>

# %%
#This line creates an instance of the PCA class with the parameter n_components set to 2.
#It specifies that we want to reduce the dimensionality of the data to 2 principal components.
#In other words, the data will be projected into a 2D space.
pca = PCA(n_components=2)
