# %% [markdown]
# <a href="https://colab.research.google.com/github/VikaSvyat/DI_Bootcamp/blob/main/DataTypesIntro_XP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip "How Much Sleep Do Americans.zip"
# Out:
# Archive:  How Much Sleep Do Americans.zip
#   inflating: How Much Sleep Do Americans/Time Americans Spend Sleeping.csv

# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ec6a7b3d-4e2c-4d0d-8958-00a2574b304d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec6a7b3d-4e2c-4d0d-8958-00a2574b304d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# 'Credit Card Approvals (Clean Data).zip'   sample_data

# %%
# !unzip 'Credit Card Approvals (Clean Data).zip'
# Out:
# Archive:  Credit Card Approvals (Clean Data).zip
#   inflating: Credit Card Approvals (Clean Data)/clean_dataset.csv
#   inflating: Credit Card Approvals (Clean Data)/crx.csv

# %%
import pandas as pd
credit_cards = pd.read_csv('Credit Card Approvals (Clean Data)/clean_dataset.csv')

# %%
credit_cards.head()     #What does this data look like?
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
credit_cards.shape      #How much data do I have?
# Out:
# (690, 16)

# %%
credit_cards.info()     # What types? What's missing?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 86.4+ KB

# %%
credit_cards.describe() #What's the story in numbers?
# Out:
#            Gender         Age        Debt     Married  BankCustomer  \
# count  690.000000  690.000000  690.000000  690.000000    690.000000
# mean     0.695652   31.514116    4.758725    0.760870      0.763768
# std      0.460464   11.860245    4.978163    0.426862      0.425074
# min      0.000000   13.750000    0.000000    0.000000      0.000000
# 25%      0.000000   22.670000    1.000000    1.000000      1.000000
# 50%      1.000000   28.460000    2.750000    1.000000      1.000000
# 75%      1.000000   37.707500    7.207500    1.000000      1.000000
# max      1.000000   80.250000   28.000000    1.000000      1.000000
#
#        YearsEmployed  PriorDefault    Employed  CreditScore  DriversLicense  \
# count     690.000000    690.000000  690.000000    690.00000      690.000000
# mean        2.223406      0.523188    0.427536      2.40000        0.457971
# std         3.346513      0.499824    0.495080      4.86294        0.498592
# ...

# %% [markdown]
# 0   Gender        QUALITATIVE (Categorical)   NOMINAL (Named)
#
#
# ---
#
#
#  1   Age          QUANTITATIVE (Numerical)   CONTINUOUS (Measurable)
#
#
# ---
#
#
#  2   Debt          QUANTITATIVE (Numerical)  CONTINUOUS (Measurable)
#
# ---
#
#
#  3   Married       QUALITATIVE (Categorical)   NOMINAL (Named)
#
# ---
#
#
#  4   BankCustomer   QUALITATIVE (Categorical)  NOMINAL (Named)
#
# ---
#
#
#  5   Industry        QUALITATIVE (Categorical) NOMINAL (Named)
#
# ---
#
#
#  6   Ethnicity       QUALITATIVE (Categorical) NOMINAL (Named)
#
# ---
#
#
#  7   YearsEmployed   QUANTITATIVE (Numerical) CONTINUOUS (Measurable)
#
# ---
#
#
#  8   PriorDefault    QUALITATIVE (Categorical) ORDINAL (Ordered)
#
# ---
#
#
#  9   Employed        QUALITATIVE (Categorical) NOMINAL (Named)
#
# ---
#
#
#  10  CreditScore      QUANTITATIVE (Numerical)  DISCRETE (Countable)
#
# ---
#
#
#  11  DriversLicense  QUALITATIVE (Categorical) NOMINAL (Named)
#
# ---
#
#
#  12  Citizen         QUALITATIVE (Categorical) NOMINAL (Named)
#
# ---
#
#
#  13  ZipCode         QUALITATIVE (Categorical) NOMINAL (Named)
#
# ---
#
#
#  14  Income          QUANTITATIVE (Numerical)CONTINUOUS (Measurable)
#
# ---
#
#
#  15  Approved         QUALITATIVE (Categorical) NOMINAL (Named)

# %% [markdown]
#     • sepal_length (cm)  ← Length of outer petals - QUANTITATIVE (Numerical)CONTINUOUS (Measurable)
#
# ---
#
#
#     • sepal_width (cm)   ← Width of outer petals QUANTITATIVE (Numerical)CONTINUOUS (Measurable)
#
# ---
#
#
#     • petal_length (cm)  ← Length of inner petals QUANTITATIVE (Numerical)CONTINUOUS (Measurable)
#
# ---
#
#
#     • petal_width (cm)   ← Width of inner petals QUANTITATIVE (Numerical)CONTINUOUS (Measurable)
#
# ---
#
#
#     • species            ← setosa, versicolor, virginica QUALITATIVE (Categorical) NOMINAL (Named)

# %%
import pandas as pd

# %%
# Load the Iris dataset from sklearn (it's built-in)
from sklearn.datasets import load_iris

# Load the raw data
iris_data = load_iris()

# Create a DataFrame
df = pd.DataFrame(
    data=iris_data.data,
    columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
)

# Add the species column
# Convert numbers (0,1,2) to names (setosa, versicolor, virginica)
df['species'] = [iris_data.target_names[i] for i in iris_data.target]

# Show that it worked
print(f"Dataset loaded successfully!")
print(f"Shape: {df.shape[0]} rows × {df.shape[1]} columns")
# Out:
# Dataset loaded successfully!
# Shape: 150 rows × 5 columns

# %%
#Calculate the mean, median, and mode of a quantitative column.
print(f"sepal_length.mean: {df['sepal_length'].mean():.2f}\t\tsepal_width.mean: {df['sepal_width'].mean():.2f}")
print(f"sepal_length.median: {df['sepal_length'].median():.2f}\tsepal_width.median: {df['sepal_width'].median():.2f}")
print(f"sepal_length.mode: {df['sepal_length'].mode()[0]}\t\tsepal_width.mode: {df['sepal_width'].mode()[0]}")
print(f"\npetal_length.mean: {df['petal_length'].mean():.2f}\t\tpetal_width.mean: {df['petal_width'].mean():.2f}")
print(f"petal_length.median: {df['petal_length'].median():.2f}\tpetal_width.median: {df['petal_width'].median():.2f}")
print(f"petal_length.mode: {df['petal_length'].mode()[0]}\t\tpetal_width.mode: {df['petal_width'].mode()[0]}")
# Out:
# sepal_length.mean: 5.84		sepal_width.mean: 3.06
# sepal_length.median: 5.80	sepal_width.median: 3.00
# sepal_length.mode: 5.0		sepal_width.mode: 3.0
#
# petal_length.mean: 3.76		petal_width.mean: 1.20
# petal_length.median: 4.35	petal_width.median: 1.30
# petal_length.mode: 1.4		petal_width.mode: 0.2

# %%
import matplotlib.pyplot as plt  # plt is the universal convention
import seaborn as sns            # sns is the universal convention

# Set style for nice-looking plots
sns.set_style("whitegrid")  # Clean background with grid
plt.rcParams['figure.figsize'] = [10, 6]  # Default size

#plt.boxplot(df['species'], df['petal_length'])
#plt.show()
# 1. Statistics
mean_pw = df['petal_width'].mean()
median_pw = df['petal_width'].median()
print(f"\nMean: {mean_pw:.2f} cm")
print(f"Median: {median_pw:.2f} cm")
print(f"Difference: {abs(mean_pw - median_pw):.2f} cm")
print("→ Mean and median are fairly close, slight right skew")

# 2 & 3. Visualizations
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram
sns.histplot(data=df, x='petal_width', bins=15, kde=True, ax=axes[0])
axes[0].axvline(mean_pw, color='red', linestyle='--', label=f'Mean: {mean_pw:.2f}')
axes[0].axvline(median_pw, color='green', linestyle='--', label=f'Median: {median_pw:.2f}')
axes[0].set_title('Distribution of Petal Width')
axes[0].legend()

# Box plot
sns.boxplot(data=df, x='species', y='petal_width', palette='Set2', ax=axes[1])
axes[1].set_title('Petal Width by Species')

plt.tight_layout()
plt.show()
# Out:
# Mean: 1.20 cm
# Median: 1.30 cm
# Difference: 0.10 cm
# → Mean and median are fairly close, slight right skew
# /tmp/ipython-input-81042040.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='species', y='petal_width', palette='Set2', ax=axes[1])

# %%
# !ls
# !unzip 'How Much Sleep Do Americans.zip'
# Out:
# 'Credit Card Approvals (Clean Data)'	  'How Much Sleep Do Americans.zip'
# 'Credit Card Approvals (Clean Data).zip'   sample_data
# Archive:  How Much Sleep Do Americans.zip
#   inflating: How Much Sleep Do Americans/Time Americans Spend Sleeping.csv

# %%
asl = pd.read_csv('How Much Sleep Do Americans/Time Americans Spend Sleeping.csv')

# %%
df.head()     - What does this data look like?
2. df.shape      - How much data do I have?
3. df.info()     - What types? What's missing?
4. df.describe()

# %%
asl.describe()
# Out:
#             index         Year  Avg hrs per day sleeping  Standard Error
# count  945.000000   945.000000                945.000000      945.000000
# mean   472.000000  2010.000000                  8.806868        0.086958
# std    272.942302     4.322782                  0.545001        0.034631
# min      0.000000  2003.000000                  7.720000        0.018000
# 25%    236.000000  2006.000000                  8.360000        0.063000
# 50%    472.000000  2010.000000                  8.810000        0.084000
# 75%    708.000000  2014.000000                  9.190000        0.106000
# max    944.000000  2017.000000                 10.650000        0.228000

# %%
asl['Period'].unique()
# Out:
# array(['Annual'], dtype=object)

# %%
asl.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
hrs_y_min = 10
hrs_y_max = 0
age_y_max = age_y_min = ''
for year in asl['Year'].unique():
  hrs_gr_min = 10
  hrs_gr_max = 0
  age_rg_max = age_rg_min = ''
  for age_gr in asl['Age Group'].unique():
    avg = asl[(asl['Age Group'] == age_gr)&(asl['Year']==year)]['Avg hrs per day sleeping'].mean()
    mdn = asl[(asl['Age Group'] == age_gr)&(asl['Year']==year)]['Avg hrs per day sleeping'].median()
    if avg > hrs_gr_max:
      hrs_gr_max = avg
      age_rg_max=age_gr
    if avg < hrs_gr_min:
      hrs_gr_min = avg
      age_rg_min=age_gr
    if avg > hrs_y_max:
      hrs_y_max = avg
      age_y_max=age_gr
    if avg < hrs_y_min:
      hrs_y_min = avg
      age_y_min=age_gr
    #print(f"In {year} group of {age_gr} slept: mean {avg:.2f} median {mdn:.2f}\t diff={abs(avg-mdn):.1f}")
    #print(f"Group of {age_gr} in {year} slept: mean {avg:.2f} median {mdn:.2f}")
  print(f"In {year} group of '{age_rg_min}' slept {hrs_gr_min:.1f} and '{age_rg_max}' slept {hrs_gr_max:.1f}")
print(f"Less of all '{age_y_min}' slept {hrs_y_min:.1f} hours. Champion of sleaping are '{age_y_max}' with {hrs_y_max:.1f}")
# Out:
# In 2003 group of '45 to 54 years' slept 8.3 and '15 to 24 years' slept 9.3
# In 2004 group of '45 to 54 years' slept 8.3 and '15 to 24 years' slept 9.4
# In 2005 group of '45 to 54 years' slept 8.3 and '15 to 24 years' slept 9.4
# In 2006 group of '45 to 54 years' slept 8.5 and '15 to 24 years' slept 9.4
# In 2007 group of '55 to 64 years' slept 8.4 and '15 to 24 years' slept 9.3
# In 2008 group of '55 to 64 years' slept 8.4 and '15 to 24 years' slept 9.4
# In 2009 group of '45 to 54 years' slept 8.4 and '15 to 24 years' slept 9.6
# In 2010 group of '45 to 54 years' slept 8.4 and '15 to 24 years' slept 9.4
# In 2011 group of '45 to 54 years' slept 8.5 and '15 to 24 years' slept 9.5
# In 2012 group of '55 to 64 years' slept 8.6 and '15 to 24 years' slept 9.5
# In 2013 group of '55 to 64 years' slept 8.6 and '15 to 24 years' slept 9.5
# In 2014 group of '55 to 64 years' slept 8.5 and '15 to 24 years' slept 9.6
# ...
